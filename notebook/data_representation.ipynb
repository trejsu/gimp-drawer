# %% [markdown]
# # Reprezentacja obrazów podczas rysowania

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from src.gimp.draw_rectangle import draw_rectangle

# %%
green = (0.32, 0.74, 0.10)
purple = (0.5529412, 0.4627451, 0.8509804)

# %%
def draw(y_):
    path_to_image_results = '../result/gimp_images/nn/square_parameters'
    name = 'jupyter_test.png'
    draw_rectangle(name=name, size=400, x=y_[4], y=y_[5], w=y_[6], h=y_[7], r=y_[0], g=y_[1], b=y_[2], a=y_[3], 
                   rotation=y_[8])
    return plt.imread('%s/%s' % (path_to_image_results, name))[:,:,:3]

# %%
image = plt.imread('../data/image/hatch.png')[:,:,:3]
plt.imshow(image)

# %%
drawned = draw([purple[0], purple[1], purple[2], 1., 0., 0.5, 1., 0.2, 0.5])
plt.imshow(drawned)

# %%
diff = abs(image - drawned)
plt.imshow(diff)
# Out:
# [0.5529412 0.4627451 0.8509804]
# [0.5529412 0.4627451 0.8509804]
# [0. 0. 0.]

# %% [markdown]
# Intuicyjnie, sieć powinna się nauczyć, że potrzeba poprawić obrazek "najbardziej" tam gdzie jest najbardziej białe - czyli tam gdzie jest największa wartość liczbowa. Miejsca bliskie zeru oznaczają miejsca gdzie obrazek jest już "bardzo" podobny do oryginału.

# %%
drawned = draw([0., 0., 0., 1., 0., 0., 0.1, 0.1, 0.5])
plt.imshow(drawned)

# %%
diff = abs(image - drawned)
plt.imshow(diff)

# %% [markdown]
# Abs odpada, bo pokazuje tylko "intensywność" błędu - nie ma info o kolorze. Przykładowo wyżej wokół oczu powinniśmy poprawic rysując czarnym, a lewy góryny róg powinniśmy poprawic rysując białym.

# %%
three = plt.imread('../data/image/three_shapes.png')[:,:,:3]
plt.imshow(three)

# %%
one = plt.imread('../data/image/square.png')[:,:,:3]
plt.imshow(one)

# %%
plt.imshow(abs(three - one))
