# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pylab as plt
from scipy import misc

# %%
PATH = "../dataset/images/"
NAME = "train"
PART = 1
PATH_TO_SRC = "../resources/scaled_images/"

X = np.load(PATH + "%s_X_%d.npy" % (NAME, PART), mmap_mode="r")
Y = np.load(PATH + "%s_Y_%d.npy" % (NAME, PART), mmap_mode="r")
labels = np.load(PATH + "%s_labels_%d.npy" % (NAME, PART), mmap_mode="r")

# %%
INDEX = 999

# %%
item = X[INDEX,:]
plt.imshow(np.abs(item))

# %%
label = labels[INDEX,:]
src = misc.imread(PATH_TO_SRC + str(label[0]) + ".jpg")
src = src / 255.
src = misc.imresize(src, (50, 50))
plt.imshow(src)

# %%
drawed = item + src
plt.imshow(-drawed)
print "action", label[1]
# Out:
# action 15

# %%
print Y[INDEX,:]
# Out:
# [ 0.56167834  0.36755459  0.17428249  0.94485898  0.32809309  0.86775447
#   0.38454318  0.82647404  0.07990137]
